# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Replace 'path_to_file' with the actual path to your CSV file
df = pd.read_csv('D:/UpGrad_Notes/ljmu immersion/Research/interim report/Coding/nifti/Patient200Master.csv')

# %%
df.head()
# Out:
#                                           Series UID          Collection  \
# 0  1.3.6.1.4.1.14519.5.2.1.4219.6651.201203836389...  FDG-PET-CT-Lesions
# 1  1.3.6.1.4.1.14519.5.2.1.4219.6651.685145825998...  FDG-PET-CT-Lesions
# 2  1.3.6.1.4.1.14519.5.2.1.4219.6651.151532511484...  FDG-PET-CT-Lesions
# 3  1.3.6.1.4.1.14519.5.2.1.4219.6651.313152023416...  FDG-PET-CT-Lesions
# 4  1.3.6.1.4.1.14519.5.2.1.4219.6651.331726561677...  FDG-PET-CT-Lesions
#
#   3rd Party Analysis  Data Description URI        Subject ID  \
# 0                 NO                   NaN  PETCT_0011f3deaf
# 1                 NO                   NaN  PETCT_0011f3deaf
# 2                 NO                   NaN  PETCT_01140d52d8
# 3                 NO                   NaN  PETCT_01140d52d8
# 4                 NO                   NaN  PETCT_0011f3deaf
#
#                                            Study UID  \
# 0  1.3.6.1.4.1.14519.5.2.1.4219.6651.389860614478...
# ...

# %%
df.describe()
# Out:
#        Data Description URI  Number of Images
# count                   0.0        636.000000
# mean                    NaN        341.603774
# std                     NaN        363.620855
# min                     NaN          1.000000
# 25%                     NaN          1.000000
# 50%                     NaN        326.000000
# 75%                     NaN        391.000000
# max                     NaN       2651.000000

# %%
unique_study_uids = df['Study UID'].nunique()
print("Number of unique Study UID:", unique_study_uids)
# Out:
# Number of unique Study UID: 212

# %%
df['age_modified'] = df['age'].str.extract('(\d+)').astype(int)

# %%
df_agecount=df.drop_duplicates(subset=['age_modified','Study UID'])

# %%
df_agecount.head()
# Out:
#                                            Series UID          Collection  \
# 0   1.3.6.1.4.1.14519.5.2.1.4219.6651.201203836389...  FDG-PET-CT-Lesions
# 2   1.3.6.1.4.1.14519.5.2.1.4219.6651.151532511484...  FDG-PET-CT-Lesions
# 5   1.3.6.1.4.1.14519.5.2.1.4219.6651.146136900202...  FDG-PET-CT-Lesions
# 8   1.3.6.1.4.1.14519.5.2.1.4219.6651.544791134209...  FDG-PET-CT-Lesions
# 11  1.3.6.1.4.1.14519.5.2.1.4219.6651.127912095193...  FDG-PET-CT-Lesions
#
#    3rd Party Analysis  Data Description URI        Subject ID  \
# 0                  NO                   NaN  PETCT_0011f3deaf
# 2                  NO                   NaN  PETCT_01140d52d8
# 5                  NO                   NaN  PETCT_0117d7f11f
# 8                  NO                   NaN  PETCT_0143bab87a
# 11                 NO                   NaN  PETCT_01682f60c3
#
#                                             Study UID  \
# 0   1.3.6.1.4.1.14519.5.2.1.4219.6651.389860614478...
# ...

# %%
plt.figure(figsize=(8, 6))
sns.histplot(df_agecount['age_modified'], kde=True, bins=20)
plt.xlabel('Age')
plt.ylabel('Count')
plt.title('Age Distribution')
plt.xticks(rotation=45)  # Rotate the x-axis labels by 45 degrees
plt.xticks(fontsize=8)
plt.tight_layout()  # Adjust spacing between subplots
plt.show()

# %%
df_diag=df.drop_duplicates(subset=['diagnosis','Study UID'])

# %%
plt.figure(figsize=(8, 6))
sns.histplot(df_diag['diagnosis'], kde=True, bins=20)
plt.xlabel('diagnosis')
plt.ylabel('Count')
plt.title('diagnosis Distribution')
plt.xticks(rotation=45)  # Rotate the x-axis labels by 45 degrees
plt.xticks(fontsize=8)
plt.tight_layout()  # Adjust spacing between subplots
plt.show()

# %%
df_sex=df.drop_duplicates(subset=['sex','age_modified','Study UID'])

# %%
plt.figure(figsize=(8, 6))
sns.histplot(df_sex['sex'], kde=True, bins=20)
plt.xlabel('Sex')
plt.ylabel('Count')
plt.title('Sex Distribution')
plt.xticks(rotation=45)  # Rotate the x-axis labels by 45 degrees
plt.xticks(fontsize=8)
plt.tight_layout()  # Adjust spacing between subplots
plt.show()

# %%
plt.figure(figsize=(6, 6))
df_sex['diagnosis'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title('Diagnosis Distribution')
plt.ylabel('')
plt.show()

# %%
df_sexunique=df.drop_duplicates(subset=['sex','age_modified','diagnosis','Study UID'])

# %%
df_sexunique
# Out:
#                                             Series UID          Collection  \
# 0    1.3.6.1.4.1.14519.5.2.1.4219.6651.201203836389...  FDG-PET-CT-Lesions
# 2    1.3.6.1.4.1.14519.5.2.1.4219.6651.151532511484...  FDG-PET-CT-Lesions
# 5    1.3.6.1.4.1.14519.5.2.1.4219.6651.146136900202...  FDG-PET-CT-Lesions
# 8    1.3.6.1.4.1.14519.5.2.1.4219.6651.544791134209...  FDG-PET-CT-Lesions
# 11   1.3.6.1.4.1.14519.5.2.1.4219.6651.127912095193...  FDG-PET-CT-Lesions
# ..                                                 ...                 ...
# 620  1.3.6.1.4.1.14519.5.2.1.4219.6651.153176287603...  FDG-PET-CT-Lesions
# 622  1.3.6.1.4.1.14519.5.2.1.4219.6651.112330519220...  FDG-PET-CT-Lesions
# 626  1.3.6.1.4.1.14519.5.2.1.4219.6651.127589643847...  FDG-PET-CT-Lesions
# 630  1.3.6.1.4.1.14519.5.2.1.4219.6651.158299964670...  FDG-PET-CT-Lesions
# 633  1.3.6.1.4.1.14519.5.2.1.4219.6651.132385355846...  FDG-PET-CT-Lesions
#
#     3rd Party Analysis  Data Description URI        Subject ID  \
# ...

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x='age_modified', y='diagnosis', data=df_sexunique)
plt.xlabel('Age')
plt.ylabel('Diagnosis')
plt.title('Diagnosis vs. Age Scatter Plot')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x='diagnosis', y='age_modified', data=df_sexunique)
plt.xlabel('Diagnosis')
plt.ylabel('Age')
plt.title('Age Distribution by Diagnosis')
plt.show()

# %%
average_age_by_diagnosis = df_sexunique.groupby('diagnosis')['age_modified'].mean().reset_index()
plt.figure(figsize=(8, 6))
sns.barplot(x='diagnosis', y='age_modified', data=average_age_by_diagnosis)
plt.xlabel('Diagnosis')
plt.ylabel('Average Age')
plt.title('Average Age by Diagnosis')
plt.show()
