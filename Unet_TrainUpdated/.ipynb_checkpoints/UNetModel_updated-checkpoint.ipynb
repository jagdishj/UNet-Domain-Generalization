# %%
import torch
print("Cuda_available? ", torch.cuda.is_available())
print("Name: ", torch.cuda.get_device_name(0))
print("Device count: ", torch.cuda.device_count())
print("current device: ", torch.cuda.current_device())
print("Select device: ", torch.cuda.device(0))
print("get device name: ",torch.cuda.get_device_name(0))
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu') #finally got the solution
# Out:
# Cuda_available?  True
# Name:  NVIDIA RTX A5000
# Device count:  1
# current device:  0
# Select device:  <torch.cuda.device object at 0x7f59b016fdc0>
# get device name:  NVIDIA RTX A5000

# %%
data_dir = 'data/ZIP'

# %%
import glob
import os
import nibabel as nib
from monai.data import CacheDataset,    Dataset,    DataLoader,    decollate_batch
from monai.networks.nets import UNet
from monai.losses import DiceLoss
from monai.networks.layers import Norm
from monai.metrics import DiceMetric
from monai.transforms import AsDiscrete
from monai.inferers import sliding_window_inference
from monai.transforms import Resize
import numpy as np

# %%
images_pt = sorted(glob.glob(os.path.join(data_dir, 'PETCT*', '*', "SUV*")))
images_ct = sorted(glob.glob(os.path.join(data_dir, 'PETCT*', '*', "CTres*")))
images_sg = sorted(glob.glob(os.path.join(data_dir, 'PETCT*', '*', "SEG*")))
data_dicts = [
            {"image_pt": image_name_pt, "image_ct": image_name_ct, "image_sg": image_name_sg}
            for image_name_pt, image_name_ct, image_name_sg in zip(images_pt, images_ct, images_sg)
        ]
keys = ["image_pt", "image_ct", "image_sg"]
train_files, val_files = data_dicts[:70], data_dicts[70:]

# %%
from monai.transforms import (
Compose,
LoadImaged,
EnsureChannelFirstd,
Spacingd,
Orientationd,
ScaleIntensityRanged,
CropForegroundd,
ConcatItemsd,
DivisiblePadd,
AddChanneld,
RandCropByPosNegLabeld,
RandFlipd,EnsureTyped,
RandRotate90d,
RandShiftIntensityd,
Resized
)

# %%
crop_val = 96
train_transforms = Compose(
    [
        LoadImaged(keys=keys),
        AddChanneld(keys=keys),
        ScaleIntensityRanged(
            keys=["image_ct"], a_min=-100, a_max=250,
             b_min=0.0, b_max=1.0, clip=True,
        ),
        ScaleIntensityRanged(
            keys=["image_pt"], a_min=0, a_max=15,
            b_min=0.0, b_max=1.0, clip=True,
        ),
        #CropForegroundd(keys=["image_ct", "image_pt"], source_key="image_ct"),
        Orientationd(keys=keys, axcodes="LAS"),
        # Resized(keys=keys, spatial_size=(256, 256, 256)), # resizing all keys
        ConcatItemsd(keys=["image_pt", "image_ct"], name="image_petct", dim=0),
        # Add some augmentations
        RandCropByPosNegLabeld(keys=["image_petct", "image_sg"], label_key="image_sg", spatial_size=(crop_val, crop_val, crop_val), pos=1, neg=1,
            num_samples=6,
            image_key="image_petct",
            image_threshold=0,
        ),
        RandRotate90d(
            keys=["image_petct", "image_sg"],
            prob=0.10,
            max_k=3,
        ),
        RandFlipd(
            keys=["image_petct", "image_sg"],
            spatial_axis=[0, 1, 2],
            prob=0.10,
        ),
        RandShiftIntensityd(
            keys=["image_petct"],
            offsets=0.10,
            prob=0.50,
        ),
        EnsureTyped(keys=["image_petct", "image_sg"]),
    ]
)

# %%
val_transforms = Compose(
    [
        LoadImaged(keys=keys),
        AddChanneld(keys=keys),
        ScaleIntensityRanged(
            keys=["image_ct"], a_min=-100, a_max=250,
            b_min=0.0, b_max=1.0, clip=True,
        ),
        ScaleIntensityRanged(
            keys=["image_pt"], a_min=0, a_max=15,
            b_min=0.0, b_max=1.0, clip=True,
        ),
        #CropForegroundd(keys=["image_ct", "image_pt"], source_key="image_ct"),
        Orientationd(keys=keys, axcodes="LAS"),
        # Resized(keys=keys, spatial_size=(256, 256, 256)), # resizing all keys
        ConcatItemsd(keys=["image_pt", "image_ct"], name="image_petct", dim=0),
        EnsureTyped(keys=["image_petct", "image_sg"]),
    ]
)

# %%
train_ds = CacheDataset(data=train_files, transform=train_transforms, cache_rate=0.03)
#train_ds = Dataset(data=train_files, transform=train_transforms)
val_ds = CacheDataset(data=val_files, transform=val_transforms, cache_rate=0.05)
#val_ds = Dataset(data=val_files, transform=val_transforms)
# Out:
# Loading dataset: 100%|██████████| 2/2 [00:06<00:00,  3.27s/it]
# Loading dataset: 100%|██████████| 1/1 [00:03<00:00,  3.33s/it]

# %%
# Create UNet, DiceLoss and Adam optimizer
device = torch.device("cuda:0")
model = UNet(
    spatial_dims=3,
    in_channels=2,
    out_channels=1,
    channels=(16, 32, 64, 128, 256),
    strides=(2, 2, 2, 2),
    num_res_units=2,
    norm=Norm.BATCH
).to(device)

loss_function = DiceLoss(to_onehot_y=2, softmax=True)
lr = 1e-3
optimizer = torch.optim.Adam(model.parameters(), lr)
dice_metric = DiceMetric(include_background=True, reduction="mean")

# %%
train_loader = DataLoader(train_ds, batch_size=1, shuffle=True, num_workers=0)
val_loader  = DataLoader(val_ds, batch_size=1, shuffle=True, num_workers=0)

# %%
#tranformation check
for batch_data in train_loader:
  label = batch_data["image_sg"]
  label = label != 0
        #print('The label values: ', np.unique(label))
  print(label.shape)

  inputs, labels = (
     batch_data["image_petct"].to(device),
     label.to(device),
  )
  print(inputs.shape)
  print(labels.shape)
  break
# Out:
# torch.Size([6, 1, 96, 96, 96])
# torch.Size([6, 2, 96, 96, 96])
# torch.Size([6, 1, 96, 96, 96])

# %%
max_epochs = 50
val_interval = 1
best_metric = -1
best_metric_epoch = -1
epoch_loss_values = []
metric_values = []
post_pred = Compose([AsDiscrete(argmax=True, to_onehot=2)])
post_label = Compose([AsDiscrete(to_onehot=2)])
checkpoint_path = os.path.join(data_dir, "checkpoint.pth")

if os.path.exists(checkpoint_path):
    checkpoint = torch.load(checkpoint_path)
    model.load_state_dict(checkpoint['model_state_dict'])
    optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
    start_epoch = checkpoint['epoch']
    best_metric = checkpoint['best_metric']
    best_metric_epoch = checkpoint['best_metric_epoch']
    epoch_loss_values = checkpoint['epoch_loss_values']
    metric_values = checkpoint['metric_values']
else:
    start_epoch = 0

for epoch in range(start_epoch,max_epochs):
    print("-" * 10)
    print(f"epoch {epoch + 1}/{max_epochs}")
    model.train()
    epoch_loss = 0
    step = 0
    for batch_data in train_loader:
        step += 1
        inputs, labels = (
            batch_data["image_petct"].to(device),
            batch_data["image_sg"].to(device),
        )
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = loss_function(outputs, labels)
        loss.backward()
        optimizer.step()
        epoch_loss += loss.item()
        print(f"{step}/{len(train_ds) // train_loader.batch_size}, " f"train_loss: {loss.item():.4f}")
    epoch_loss /= step
    epoch_loss_values.append(epoch_loss)
    print(f"epoch {epoch + 1} average loss: {epoch_loss:.4f}")
    if epoch % 7 == 0 :
        torch.save({
            'epoch': epoch + 1,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'best_metric': best_metric,
            'best_metric_epoch': best_metric_epoch,
            'epoch_loss_values': epoch_loss_values,
            'metric_values': metric_values
        }, checkpoint_path)

    if (epoch + 1) % val_interval == 0:
        model.eval()
        with torch.no_grad():
            for val_data in val_loader:
                val_inputs, val_labels = (
                    val_data["image_petct"].to(device),
                    val_data["image_sg"].to(device),
                )
                roi_size = (160, 160, 160)
                sw_batch_size = 4
                val_outputs = sliding_window_inference(val_inputs, roi_size, sw_batch_size, model)
                val_outputs = [post_pred(i) for i in decollate_batch(val_outputs)]
                val_labels = [post_label(i) for i in decollate_batch(val_labels)]
                # compute metric for current iteration
                dice_metric(y_pred=val_outputs, y=val_labels)

            # aggregate the final mean dice result
            metric = dice_metric.aggregate().item()
            # reset the status for next validation round
            dice_metric.reset()

            metric_values.append(metric)
            if metric > best_metric:
                best_metric = metric
                best_metric_epoch = epoch + 1
                torch.save(model.state_dict(), os.path.join(data_dir, "best_metric_model.pth"))
                print("saved new best metric model")
            print(
                f"current epoch: {epoch + 1} current mean dice: {metric:.4f}"
                f"\nbest mean dice: {best_metric:.4f} "
                f"at epoch: {best_metric_epoch}"
            )
# Out:
# ----------
# epoch 1/50
# /opt/conda/lib/python3.10/site-packages/monai/losses/dice.py:138: UserWarning: single channel prediction, `softmax=True` ignored.
#   warnings.warn("single channel prediction, `softmax=True` ignored.")
# /opt/conda/lib/python3.10/site-packages/monai/losses/dice.py:147: UserWarning: single channel prediction, `to_onehot_y=True` ignored.
#   warnings.warn("single channel prediction, `to_onehot_y=True` ignored.")
# 1/70, train_loss: 0.9497
# /opt/conda/lib/python3.10/site-packages/monai/transforms/utils.py:561: UserWarning: Num foregrounds 0, Num backgrounds 36384158, unable to generate class balanced samples, setting `pos_ratio` to 0.
#   warnings.warn(
# 2/70, train_loss: 1.0000
# 3/70, train_loss: 0.8413
# 4/70, train_loss: 0.9929
# 5/70, train_loss: 0.9273
# 6/70, train_loss: 0.8773
# 7/70, train_loss: 0.9460
# /opt/conda/lib/python3.10/site-packages/monai/transforms/utils.py:561: UserWarning: Num foregrounds 0, Num backgrounds 20040136, unable to generate class balanced samples, setting `pos_ratio` to 0.
#   warnings.warn(
# 8/70, train_loss: 1.0000
# 9/70, train_loss: 0.6086
# 10/70, train_loss: 0.9999
# 11/70, train_loss: 0.6413
# 12/70, train_loss: 0.4356
# /opt/conda/lib/python3.10/site-packages/monai/transforms/utils.py:561: UserWarning: Num foregrounds 0, Num backgrounds 20483549, unable to generate class balanced samples, setting `pos_ratio` to 0.
#   warnings.warn(
# 13/70, train_loss: 1.0000
# 14/70, train_loss: 1.0041
# 15/70, train_loss: 1.1322
# 16/70, train_loss: 0.8584
# 17/70, train_loss: 1.0067
# 18/70, train_loss: 0.9933
# 19/70, train_loss: 0.9552
# 20/70, train_loss: 0.9999
# 21/70, train_loss: 0.9995
# 22/70, train_loss: 0.9940
# 23/70, train_loss: 0.9936
# 24/70, train_loss: 0.9861
# 25/70, train_loss: 0.9931
# /opt/conda/lib/python3.10/site-packages/monai/transforms/utils.py:561: UserWarning: Num foregrounds 0, Num backgrounds 26885554, unable to generate class balanced samples, setting `pos_ratio` to 0.
#   warnings.warn(
# 26/70, train_loss: 1.0000
# 27/70, train_loss: 0.9832
# 28/70, train_loss: 0.9864
# 29/70, train_loss: 0.9845
# 30/70, train_loss: 0.9668
# 31/70, train_loss: -2.6823
# 32/70, train_loss: 1.0000
# 33/70, train_loss: 1.0156
# /opt/conda/lib/python3.10/site-packages/monai/transforms/utils.py:561: UserWarning: Num foregrounds 0, Num backgrounds 23287246, unable to generate class balanced samples, setting `pos_ratio` to 0.
#   warnings.warn(
# 34/70, train_loss: 1.0000
# 35/70, train_loss: 1.0438
# /opt/conda/lib/python3.10/site-packages/monai/transforms/utils.py:561: UserWarning: Num foregrounds 0, Num backgrounds 24500794, unable to generate class balanced samples, setting `pos_ratio` to 0.
#   warnings.warn(
# 36/70, train_loss: 1.0000
# 37/70, train_loss: 0.9891
# /opt/conda/lib/python3.10/site-packages/monai/transforms/utils.py:561: UserWarning: Num foregrounds 0, Num backgrounds 19045437, unable to generate class balanced samples, setting `pos_ratio` to 0.
#   warnings.warn(
# 38/70, train_loss: 1.0000
# 39/70, train_loss: 0.9969
# 40/70, train_loss: 0.9998
# 41/70, train_loss: 1.0000
# /opt/conda/lib/python3.10/site-packages/monai/transforms/utils.py:561: UserWarning: Num foregrounds 0, Num backgrounds 24821888, unable to generate class balanced samples, setting `pos_ratio` to 0.
#   warnings.warn(
# 42/70, train_loss: 1.0000
# 43/70, train_loss: 0.9999
# 44/70, train_loss: 0.9872
# 45/70, train_loss: 0.9992
# 46/70, train_loss: 0.9817
# 47/70, train_loss: 1.6566
# /opt/conda/lib/python3.10/site-packages/monai/transforms/utils.py:561: UserWarning: Num foregrounds 0, Num backgrounds 23508120, unable to generate class balanced samples, setting `pos_ratio` to 0.
#   warnings.warn(
# 48/70, train_loss: 1.0000
# 49/70, train_loss: 0.9988
# 50/70, train_loss: 1.0353
# 51/70, train_loss: 1.0179
# 52/70, train_loss: 0.9986
# 53/70, train_loss: 0.9825
# /opt/conda/lib/python3.10/site-packages/monai/transforms/utils.py:561: UserWarning: Num foregrounds 0, Num backgrounds 25647697, unable to generate class balanced samples, setting `pos_ratio` to 0.
#   warnings.warn(
# 54/70, train_loss: 1.0000
# /opt/conda/lib/python3.10/site-packages/monai/transforms/utils.py:561: UserWarning: Num foregrounds 0, Num backgrounds 38903555, unable to generate class balanced samples, setting `pos_ratio` to 0.
#   warnings.warn(
# 55/70, train_loss: 1.0000
# 56/70, train_loss: 0.9929
# 57/70, train_loss: 0.9908
# 58/70, train_loss: 0.9839
# /opt/conda/lib/python3.10/site-packages/monai/transforms/utils.py:561: UserWarning: Num foregrounds 0, Num backgrounds 25075441, unable to generate class balanced samples, setting `pos_ratio` to 0.
#   warnings.warn(
# 59/70, train_loss: 1.0000
# 60/70, train_loss: 1.0000
# /opt/conda/lib/python3.10/site-packages/monai/transforms/utils.py:561: UserWarning: Num foregrounds 0, Num backgrounds 27629313, unable to generate class balanced samples, setting `pos_ratio` to 0.
#   warnings.warn(
# 61/70, train_loss: 1.0000
# 62/70, train_loss: 0.9916
# 63/70, train_loss: 1.0000
# 64/70, train_loss: 0.9992
# 65/70, train_loss: 1.0080
# 66/70, train_loss: 1.0002
# 67/70, train_loss: 0.9987
# 68/70, train_loss: 0.9976
# 69/70, train_loss: 0.7754
# 70/70, train_loss: 0.9979
# epoch 1 average loss: 0.9259
# saved new best metric model
# current epoch: 1 current mean dice: 0.5256
# best mean dice: 0.5256 at epoch: 1
# ----------
# epoch 2/50
# 1/70, train_loss: 1.0619
# 2/70, train_loss: 0.4386
# 3/70, train_loss: 1.0000
# 4/70, train_loss: 0.9487
# 5/70, train_loss: 1.0000
# 6/70, train_loss: 0.9984
# 7/70, train_loss: 0.9676
# 8/70, train_loss: 1.0000
# 9/70, train_loss: 0.9840
# 10/70, train_loss: 0.9991
# 11/70, train_loss: 1.0016
# 12/70, train_loss: 0.9657
# 13/70, train_loss: 1.1083
# 14/70, train_loss: 1.0026
# 15/70, train_loss: 0.9969
# 16/70, train_loss: 1.0000
# 17/70, train_loss: 0.9769
# 18/70, train_loss: 1.0077
# 19/70, train_loss: 0.7310
# 20/70, train_loss: 0.9952
# 21/70, train_loss: 1.0000
# 22/70, train_loss: 0.9979
# 23/70, train_loss: 0.9843
# 24/70, train_loss: 0.9671
# 25/70, train_loss: 0.9453
# 26/70, train_loss: 1.0002
# 27/70, train_loss: 1.0217
# 28/70, train_loss: 0.9998
# 29/70, train_loss: 1.0432
# 30/70, train_loss: 0.9997
# 31/70, train_loss: 1.0000
# 32/70, train_loss: 1.0644
# 33/70, train_loss: 1.0000
# 34/70, train_loss: 1.0090
# 35/70, train_loss: 1.0000
# 36/70, train_loss: 0.9842
# 37/70, train_loss: 1.0001
# 38/70, train_loss: 0.9942
# 39/70, train_loss: 0.9937
# 40/70, train_loss: 0.8896
# 41/70, train_loss: 0.9365
# 42/70, train_loss: 1.1131
# 43/70, train_loss: 1.0254
# 44/70, train_loss: 1.0000
# 45/70, train_loss: 0.9997
# 46/70, train_loss: 1.0000
# 47/70, train_loss: 0.9995
# 48/70, train_loss: 0.9869
# 49/70, train_loss: 0.9867
# 50/70, train_loss: 1.6967
# 51/70, train_loss: 0.9992
# 52/70, train_loss: 0.9977
# 53/70, train_loss: 1.0000
# 54/70, train_loss: 1.0220
# 55/70, train_loss: 0.9750
# 56/70, train_loss: 0.9442
# 57/70, train_loss: 1.0195
# 58/70, train_loss: 1.0000
# 59/70, train_loss: 0.9996
# 60/70, train_loss: 0.9995
# 61/70, train_loss: 1.0214
# 62/70, train_loss: 0.9978
# 63/70, train_loss: 1.0000
# 64/70, train_loss: 1.0000
# 65/70, train_loss: 0.9978
# 66/70, train_loss: 0.9997
# 67/70, train_loss: 0.9943
# 68/70, train_loss: 1.0005
# 69/70, train_loss: 0.9918
# 70/70, train_loss: 1.0000
# epoch 2 average loss: 0.9969
# current epoch: 2 current mean dice: 0.5256
# best mean dice: 0.5256 at epoch: 1
# ----------
# epoch 3/50
# 1/70, train_loss: 0.9238
# 2/70, train_loss: 0.9936
# 3/70, train_loss: 1.0000
# 4/70, train_loss: 1.0016
# 5/70, train_loss: 1.0004
# 6/70, train_loss: 1.0125
# 7/70, train_loss: 1.0000
# 8/70, train_loss: 1.0000
# 9/70, train_loss: 1.0135
# 10/70, train_loss: 1.0318
# 11/70, train_loss: 1.0002
# 12/70, train_loss: 0.9165
# 13/70, train_loss: 1.0031
# 14/70, train_loss: 1.0000
# 15/70, train_loss: 0.9947
# 16/70, train_loss: 0.9978
# 17/70, train_loss: 0.9998
# 18/70, train_loss: 1.0001
# 19/70, train_loss: 0.9990
# 20/70, train_loss: 0.9999
# 21/70, train_loss: 0.9998
# 22/70, train_loss: 1.1149
# 23/70, train_loss: 0.9974
# 24/70, train_loss: 1.0021
# 25/70, train_loss: 1.0865
# 26/70, train_loss: 1.0000
# 27/70, train_loss: 1.0045
# 28/70, train_loss: 1.0180
# 29/70, train_loss: 0.9307
# 30/70, train_loss: 1.0007
# 31/70, train_loss: 1.0363
# 32/70, train_loss: 1.0000
# 33/70, train_loss: 1.0000
# 34/70, train_loss: 0.8805
# 35/70, train_loss: 1.0094
# 36/70, train_loss: 1.0125
# 37/70, train_loss: 1.0000
# 38/70, train_loss: 1.0028
# 39/70, train_loss: 1.0000
# 40/70, train_loss: 1.0011
# 41/70, train_loss: 0.9995
# 42/70, train_loss: 0.9821
# 43/70, train_loss: 1.0127
# 44/70, train_loss: 0.9421
# 45/70, train_loss: 1.0000
# 46/70, train_loss: 0.9843
# 47/70, train_loss: 0.8801
# 48/70, train_loss: 0.9708
# 49/70, train_loss: 0.9853
# 50/70, train_loss: 0.9768
# 51/70, train_loss: 0.9998
# 52/70, train_loss: 1.0000
# 53/70, train_loss: 1.0000
# 54/70, train_loss: 0.9345
# 55/70, train_loss: 0.9981
# 56/70, train_loss: 0.9924
# 57/70, train_loss: 0.9980
# 58/70, train_loss: 0.9380
# 59/70, train_loss: 0.9992
# 60/70, train_loss: 0.9396
# 61/70, train_loss: 0.9959
# 62/70, train_loss: 0.9755
# 63/70, train_loss: 0.8209
# 64/70, train_loss: 0.9949
# 65/70, train_loss: 1.0000
# 66/70, train_loss: 1.0000
# 67/70, train_loss: 1.0055
# 68/70, train_loss: 1.0000
# 69/70, train_loss: 0.9227
# 70/70, train_loss: 0.9856
# epoch 3 average loss: 0.9889
# current epoch: 3 current mean dice: 0.5256
# best mean dice: 0.5256 at epoch: 1
# ----------
# epoch 4/50
# 1/70, train_loss: 1.0000
# 2/70, train_loss: 0.8900
# 3/70, train_loss: 0.9968
# 4/70, train_loss: 0.9901
# 5/70, train_loss: 0.8420
# 6/70, train_loss: 0.9841
# 7/70, train_loss: 0.9747
# 8/70, train_loss: 0.9987
# 9/70, train_loss: 0.8631
# 10/70, train_loss: 0.9945
# 11/70, train_loss: 0.9864
# 12/70, train_loss: 1.0000
# 13/70, train_loss: 0.9881
# 14/70, train_loss: 0.9432
# 15/70, train_loss: 0.9504
# 16/70, train_loss: 0.9973
# 17/70, train_loss: 0.8612
# 18/70, train_loss: 1.0000
# 19/70, train_loss: 0.9880
# 20/70, train_loss: 0.9838
# 21/70, train_loss: 0.9759
# 22/70, train_loss: 0.9989
# 23/70, train_loss: 1.0009
# 24/70, train_loss: 0.9902
# 25/70, train_loss: 0.9894
# 26/70, train_loss: 1.0000
# 27/70, train_loss: 0.8627
# 28/70, train_loss: 1.0000
# 29/70, train_loss: 0.9996
# 30/70, train_loss: 1.0000
# 31/70, train_loss: 0.9998
# 32/70, train_loss: 0.9983
# 33/70, train_loss: 1.0000
# 34/70, train_loss: 0.8802
# 35/70, train_loss: 0.9820
# 36/70, train_loss: 1.0001
# 37/70, train_loss: 0.9996
# 38/70, train_loss: 1.0000
# 39/70, train_loss: 0.9955
# 40/70, train_loss: 1.0000
# 41/70, train_loss: 0.8916
# 42/70, train_loss: 1.0007
# 43/70, train_loss: 0.9210
# 44/70, train_loss: 0.9182
# 45/70, train_loss: 0.9925
# 46/70, train_loss: 0.9348
# 47/70, train_loss: 0.9986
# 48/70, train_loss: 0.9980
# 49/70, train_loss: 0.7709
# 50/70, train_loss: 0.9979
# 51/70, train_loss: 0.9644
# 52/70, train_loss: 0.7569
# 53/70, train_loss: 0.9975
# 54/70, train_loss: 0.9932
# 55/70, train_loss: 1.0000
# 56/70, train_loss: 1.0000
# 57/70, train_loss: 0.9927
# 58/70, train_loss: 0.9990
# 59/70, train_loss: 0.7808
# 60/70, train_loss: 0.9937
# 61/70, train_loss: 0.9535
# 62/70, train_loss: 0.9998
# 63/70, train_loss: 1.0000
# 64/70, train_loss: 1.0004
# 65/70, train_loss: 0.9999
# 66/70, train_loss: 0.8945
# 67/70, train_loss: 1.0000
# 68/70, train_loss: 1.0000
# 69/70, train_loss: 0.9766
# 70/70, train_loss: 1.0000
# epoch 4 average loss: 0.9662
# current epoch: 4 current mean dice: 0.5256
# best mean dice: 0.5256 at epoch: 1
# ----------
# epoch 5/50
# 1/70, train_loss: 0.9119
# 2/70, train_loss: 0.9961
# 3/70, train_loss: 1.0000
# 4/70, train_loss: 0.9886
# 5/70, train_loss: 0.8650
# 6/70, train_loss: 0.8992
# 7/70, train_loss: 1.0000
# 8/70, train_loss: 0.9269
# 9/70, train_loss: 0.9995
# 10/70, train_loss: 0.9878
# 11/70, train_loss: 0.8694
# 12/70, train_loss: 0.9605
# 13/70, train_loss: 0.9959
# 14/70, train_loss: 0.9987
# 15/70, train_loss: 1.0000
# 16/70, train_loss: 1.0000
# 17/70, train_loss: 0.9729
# 18/70, train_loss: 0.9874
# 19/70, train_loss: 1.0000
# 20/70, train_loss: 0.9982
# 21/70, train_loss: 0.9982
# 22/70, train_loss: 0.9991
# 23/70, train_loss: 0.9684
# 24/70, train_loss: 1.0000
# 25/70, train_loss: 1.0000
# 26/70, train_loss: 0.9690
# 27/70, train_loss: 0.9993
# 28/70, train_loss: 0.9997
# 29/70, train_loss: 0.9394
# 30/70, train_loss: 1.0001
# 31/70, train_loss: 0.9963
# 32/70, train_loss: 0.9943
# 33/70, train_loss: 0.9650
# 34/70, train_loss: 0.8816
# 35/70, train_loss: 1.0005
# 36/70, train_loss: 0.9976
# 37/70, train_loss: 1.0000
# 38/70, train_loss: 1.0009
# 39/70, train_loss: 1.0110
# 40/70, train_loss: 1.9400
# 41/70, train_loss: 1.0000
# 42/70, train_loss: 0.9607
# 43/70, train_loss: 0.9998
# 44/70, train_loss: 1.2613
# 45/70, train_loss: 0.3548
# 46/70, train_loss: 0.9849
# 47/70, train_loss: 1.0000
# 48/70, train_loss: 0.9609
# 49/70, train_loss: 0.9998
# 50/70, train_loss: 0.8375
# 51/70, train_loss: 1.0000
# 52/70, train_loss: 0.6339
# 53/70, train_loss: 1.1189
# 54/70, train_loss: 0.9901
# 55/70, train_loss: 0.9986
# 56/70, train_loss: 1.0003
# 57/70, train_loss: 0.9974
# 58/70, train_loss: 1.0000
# 59/70, train_loss: 1.6919
# 60/70, train_loss: 1.0067
# 61/70, train_loss: 1.0000
# 62/70, train_loss: 1.0168
# 63/70, train_loss: 1.0000
# 64/70, train_loss: 0.9889
# 65/70, train_loss: 0.9929
# 66/70, train_loss: 0.9920
# 67/70, train_loss: 0.9984
# 68/70, train_loss: 1.0000
# 69/70, train_loss: 1.0010
# 70/70, train_loss: 1.2044
# epoch 5 average loss: 1.0001
# current epoch: 5 current mean dice: 0.5256
# best mean dice: 0.5256 at epoch: 1
# ----------
# epoch 6/50
# 1/70, train_loss: 1.0027
# 2/70, train_loss: 1.0000
# 3/70, train_loss: 1.0000
# 4/70, train_loss: 0.9071
# 5/70, train_loss: 1.1207
# 6/70, train_loss: 1.0000
# 7/70, train_loss: 1.0000
# 8/70, train_loss: 1.3754
# 9/70, train_loss: 0.9874
# 10/70, train_loss: 1.0000
# 11/70, train_loss: 1.1067
# 12/70, train_loss: 0.9999
# 13/70, train_loss: 0.9980
# 14/70, train_loss: 1.0000
# 15/70, train_loss: 1.0000
# 16/70, train_loss: 0.9632
# 17/70, train_loss: 1.0000
# 18/70, train_loss: 1.0015
# 19/70, train_loss: 1.0019
# 20/70, train_loss: 1.0250
# 21/70, train_loss: 1.0008
# 22/70, train_loss: 1.0933
# 23/70, train_loss: 1.0143
# 24/70, train_loss: 1.0012
# 25/70, train_loss: 1.0000
# 26/70, train_loss: 0.9997
# 27/70, train_loss: 1.0109
# 28/70, train_loss: 0.9271
# 29/70, train_loss: 1.0423
# 30/70, train_loss: 1.0208
# 31/70, train_loss: 0.9981
# 32/70, train_loss: 1.0005
# 33/70, train_loss: 1.0000
# 34/70, train_loss: 1.0000
# 35/70, train_loss: 0.7281
# 36/70, train_loss: 0.9484
# 37/70, train_loss: 0.9787
# 38/70, train_loss: 1.0000
# 39/70, train_loss: 0.9963
# 40/70, train_loss: 1.1061
# 41/70, train_loss: 1.0043
# 42/70, train_loss: 0.9991
# 43/70, train_loss: 0.9957
# 44/70, train_loss: 0.9559
# 45/70, train_loss: 1.0000
# 46/70, train_loss: 1.0338
# 47/70, train_loss: 1.0110
# 48/70, train_loss: 0.9999
# 49/70, train_loss: 0.9935
# 50/70, train_loss: 0.9983
# 51/70, train_loss: 0.9971
# 52/70, train_loss: 0.9752
# 53/70, train_loss: 0.9545
# 54/70, train_loss: 1.0000
# 55/70, train_loss: 1.0512
# 56/70, train_loss: 0.9756
# 57/70, train_loss: 1.0472
# 58/70, train_loss: -0.2086
# 59/70, train_loss: 1.0000
# 60/70, train_loss: 1.0481
# 61/70, train_loss: -4.8055
# 62/70, train_loss: 0.9991
# 63/70, train_loss: 0.9949
# 64/70, train_loss: 0.9981
# 65/70, train_loss: 1.0132
# 66/70, train_loss: 0.9996
# 67/70, train_loss: 1.2520
# 68/70, train_loss: 0.9862
# 69/70, train_loss: 1.5164
# 70/70, train_loss: 0.9053
# epoch 6 average loss: 0.9150
# current epoch: 6 current mean dice: 0.5256
# best mean dice: 0.5256 at epoch: 1
# ----------
# epoch 7/50
# 1/70, train_loss: 1.0000
# 2/70, train_loss: 0.9040
# 3/70, train_loss: 1.0000
# 4/70, train_loss: 0.9800
# 5/70, train_loss: 0.8861
# 6/70, train_loss: 0.9994
# 7/70, train_loss: 1.0051
# 8/70, train_loss: 0.8592
# 9/70, train_loss: 1.0000
# 10/70, train_loss: 0.8890
# 11/70, train_loss: 0.9945
# 12/70, train_loss: 0.9861
# 13/70, train_loss: 0.7783
# 14/70, train_loss: 1.0000
# 15/70, train_loss: 0.9976
# 16/70, train_loss: 0.7120
# 17/70, train_loss: 1.0000
# 18/70, train_loss: 0.9876
# 19/70, train_loss: 0.8691
# 20/70, train_loss: 0.8003
# 21/70, train_loss: 1.0000
# 22/70, train_loss: 0.9999
# 23/70, train_loss: 0.9965
# 24/70, train_loss: 1.3276
# 25/70, train_loss: 0.9989
# 26/70, train_loss: 0.9626
# 27/70, train_loss: 0.9608
# 28/70, train_loss: 0.9569
# 29/70, train_loss: 0.9861
# 30/70, train_loss: 0.9381
# 31/70, train_loss: 1.0000
# 32/70, train_loss: 0.9473
# 33/70, train_loss: 0.8459
# 34/70, train_loss: 1.0000
# 35/70, train_loss: 0.9905
# 36/70, train_loss: 0.8663
# 37/70, train_loss: 0.9994
# 38/70, train_loss: 0.9919
# 39/70, train_loss: 0.9994
# 40/70, train_loss: 0.9972
# 41/70, train_loss: 0.9998
# 42/70, train_loss: 1.0000
# 43/70, train_loss: 1.0000
# 44/70, train_loss: 0.9823
# 45/70, train_loss: 0.8861
# 46/70, train_loss: 0.9993
# 47/70, train_loss: 0.8158
# 48/70, train_loss: 1.0000
# 49/70, train_loss: 0.9983
# 50/70, train_loss: 0.9150
# 51/70, train_loss: 0.9992
# 52/70, train_loss: 0.9934
# 53/70, train_loss: 1.0000
# 54/70, train_loss: 0.6510
# 55/70, train_loss: 0.9293
# 56/70, train_loss: 0.8219
# 57/70, train_loss: 0.8711
# 58/70, train_loss: 0.9924
# 59/70, train_loss: 0.9392
# 60/70, train_loss: 0.9895
# 61/70, train_loss: 0.9510
# 62/70, train_loss: 0.8906
# 63/70, train_loss: 0.9995
# 64/70, train_loss: 1.0000
# 65/70, train_loss: 0.9997
# 66/70, train_loss: 1.0000
# 67/70, train_loss: 0.9345
# 68/70, train_loss: 0.9778
# 69/70, train_loss: 1.0000
# 70/70, train_loss: 1.0000
# epoch 7 average loss: 0.9564
# current epoch: 7 current mean dice: 0.5256
# best mean dice: 0.5256 at epoch: 1
# ----------
# epoch 8/50
# 1/70, train_loss: 0.9990
# 2/70, train_loss: 1.0000
# 3/70, train_loss: 0.7761
# 4/70, train_loss: 1.0000
# 5/70, train_loss: 0.9994
# 6/70, train_loss: 0.9993
# 7/70, train_loss: 0.9548
# 8/70, train_loss: 0.9931
# 9/70, train_loss: 0.9966
# 10/70, train_loss: 1.0000
# 11/70, train_loss: 0.9189
# 12/70, train_loss: 0.7719
# 13/70, train_loss: 0.9989
# 14/70, train_loss: 1.0000
# 15/70, train_loss: 0.8821
# 16/70, train_loss: 0.8503
# 17/70, train_loss: 0.9720
# 18/70, train_loss: 0.9734
# 19/70, train_loss: 1.0000
# 20/70, train_loss: 0.8429
# 21/70, train_loss: 1.0000
# 22/70, train_loss: 1.0000
# 23/70, train_loss: 0.9124
# 24/70, train_loss: 0.9996
# 25/70, train_loss: 0.9903
# 26/70, train_loss: 0.9833
# 27/70, train_loss: 0.9185
# 28/70, train_loss: 1.0000
# 29/70, train_loss: 0.7385
# 30/70, train_loss: 0.9930
# 31/70, train_loss: 0.9764
# 32/70, train_loss: 0.9615
# 33/70, train_loss: 0.9503
# 34/70, train_loss: 1.0000
# 35/70, train_loss: 1.0000
# 36/70, train_loss: 0.9998
# 37/70, train_loss: 0.9198
# 38/70, train_loss: 0.8350
# 39/70, train_loss: 0.9965
# 40/70, train_loss: 0.9983
# 41/70, train_loss: 0.9312
# 42/70, train_loss: 0.9964
# 43/70, train_loss: 0.7152
# 44/70, train_loss: 0.9170
# 45/70, train_loss: 0.8525
# 46/70, train_loss: 0.9973
# 47/70, train_loss: 1.0000
# 48/70, train_loss: 0.8548
# 49/70, train_loss: 0.9034
# 50/70, train_loss: 0.9612
# 51/70, train_loss: 0.9276
# 52/70, train_loss: 1.0028
# 53/70, train_loss: 0.7575
# 54/70, train_loss: -4.7231
# 55/70, train_loss: 0.8995
# 56/70, train_loss: 0.9829
# 57/70, train_loss: 0.9998
# 58/70, train_loss: 1.0021
# 59/70, train_loss: 0.9965
# 60/70, train_loss: 1.0000
# 61/70, train_loss: 1.0000
# 62/70, train_loss: 0.9949
# 63/70, train_loss: 1.0015
# 64/70, train_loss: 1.0000
# 65/70, train_loss: 1.0158
# 66/70, train_loss: 0.9998
# 67/70, train_loss: 1.0000
# 68/70, train_loss: 1.0000
# 69/70, train_loss: 0.9293
# 70/70, train_loss: 0.9995
# epoch 8 average loss: 0.8717
# current epoch: 8 current mean dice: 0.5256
# best mean dice: 0.5256 at epoch: 1
# ----------
# epoch 9/50
# 1/70, train_loss: 0.9885
# 2/70, train_loss: 1.0001
# 3/70, train_loss: 1.0041
# 4/70, train_loss: 1.0000
# 5/70, train_loss: 1.0009
# 6/70, train_loss: 1.0000
# 7/70, train_loss: 0.9922
# 8/70, train_loss: 1.0001
# 9/70, train_loss: 1.0000
# 10/70, train_loss: 1.0418
# 11/70, train_loss: 0.9995
# 12/70, train_loss: 1.0000
# 13/70, train_loss: 1.0088
# 14/70, train_loss: 1.0000
# 15/70, train_loss: 1.0645
# 16/70, train_loss: 0.9997
# 17/70, train_loss: 1.0000
# 18/70, train_loss: 1.0003
# 19/70, train_loss: 1.0000
# 20/70, train_loss: 0.9640
# 21/70, train_loss: 0.9944
# 22/70, train_loss: 0.9945
# 23/70, train_loss: 0.9459
# 24/70, train_loss: 0.9728
# 25/70, train_loss: 1.0000
# 26/70, train_loss: 1.0000
# 27/70, train_loss: 0.9495
# 28/70, train_loss: 0.9900
# 29/70, train_loss: 1.0139
# 30/70, train_loss: 0.9962
# 31/70, train_loss: 1.0024
# 32/70, train_loss: 1.0000
# 33/70, train_loss: 1.0490
# 34/70, train_loss: 1.1375
# 35/70, train_loss: 1.0449
# 36/70, train_loss: 0.9234
# 37/70, train_loss: 0.9916
# 38/70, train_loss: 1.0033
# 39/70, train_loss: 3.6482
# 40/70, train_loss: 0.9499
# 41/70, train_loss: 1.0021
# 42/70, train_loss: 1.0012
# 43/70, train_loss: 1.0789
# 44/70, train_loss: 1.0304
# 45/70, train_loss: 1.0000
# 46/70, train_loss: 1.0193
# 47/70, train_loss: 1.0204
# 48/70, train_loss: 1.0022
# 49/70, train_loss: 0.9995
# 50/70, train_loss: 1.0180
# 51/70, train_loss: 1.0000
# 52/70, train_loss: 1.1088
# 53/70, train_loss: 1.0467
# 54/70, train_loss: 0.9992
# 55/70, train_loss: 1.0010
# 56/70, train_loss: 1.0139
# 57/70, train_loss: 1.0044
# 58/70, train_loss: 1.0083
# 59/70, train_loss: 1.0003
# 60/70, train_loss: 1.0017
# 61/70, train_loss: 1.0324
# 62/70, train_loss: -1.5069
# 63/70, train_loss: 1.0114
# 64/70, train_loss: 0.9654
# 65/70, train_loss: 1.0000
# 66/70, train_loss: 0.9994
# 67/70, train_loss: 1.0093
# 68/70, train_loss: 1.0000
# 69/70, train_loss: 1.0000
# 70/70, train_loss: 0.9693
# epoch 9 average loss: 1.0073
# current epoch: 9 current mean dice: 0.5256
# best mean dice: 0.5256 at epoch: 1
# ----------
# epoch 10/50
# 1/70, train_loss: 1.0143
# 2/70, train_loss: 1.0000
# 3/70, train_loss: 1.0000
# 4/70, train_loss: 1.0000
# 5/70, train_loss: 1.0000
# 6/70, train_loss: 0.9982
# 7/70, train_loss: 0.9998
# 8/70, train_loss: 0.8945
# 9/70, train_loss: 1.1299
# 10/70, train_loss: 1.0000
# 11/70, train_loss: 0.9993
# 12/70, train_loss: 1.0086
# 13/70, train_loss: 0.9999
# 14/70, train_loss: 1.0795
# 15/70, train_loss: 1.0299
# 16/70, train_loss: 1.0000
# 17/70, train_loss: 1.0125
# 18/70, train_loss: 1.0000
# 19/70, train_loss: 1.0004
# 20/70, train_loss: 1.0217
# 21/70, train_loss: 1.0273
# 22/70, train_loss: 0.2983
# 23/70, train_loss: 1.0078
# 24/70, train_loss: 0.9088
# 25/70, train_loss: 1.0094
# 26/70, train_loss: 0.9332
# 27/70, train_loss: 1.0000
# 28/70, train_loss: 0.9903
# 29/70, train_loss: 1.0015
# 30/70, train_loss: 1.0000
# 31/70, train_loss: 0.9791
# 32/70, train_loss: 0.9783
# 33/70, train_loss: 1.0001
# 34/70, train_loss: 1.0479
# 35/70, train_loss: 0.9996
# 36/70, train_loss: 0.9917
# 37/70, train_loss: 1.0369
# 38/70, train_loss: 0.9958
# 39/70, train_loss: 1.0079
# 40/70, train_loss: 1.0391
# 41/70, train_loss: 1.0000
# 42/70, train_loss: 1.0000
# 43/70, train_loss: 1.0003
# 44/70, train_loss: 1.0000
# 45/70, train_loss: 0.9926
# 46/70, train_loss: 0.9620
# 47/70, train_loss: 0.9996
# 48/70, train_loss: 0.9996
# 49/70, train_loss: 0.2368
# 50/70, train_loss: 1.0000
# 51/70, train_loss: 1.0209
# 52/70, train_loss: 1.0000
# 53/70, train_loss: 1.2883
# 54/70, train_loss: 1.0088
# 55/70, train_loss: 1.0121
# 56/70, train_loss: 0.6989
# 57/70, train_loss: 1.0182
# 58/70, train_loss: 1.0061
# 59/70, train_loss: 1.0012
# 60/70, train_loss: 1.0001
# 61/70, train_loss: 1.0707
# 62/70, train_loss: 0.9955
# 63/70, train_loss: 0.9033
# 64/70, train_loss: 1.0000
# 65/70, train_loss: 1.0008
# 66/70, train_loss: 1.0096
# 67/70, train_loss: 0.9876
# 68/70, train_loss: 0.9495
# 69/70, train_loss: 1.0906
# 70/70, train_loss: 1.0000
# epoch 10 average loss: 0.9814
# current epoch: 10 current mean dice: 0.5256
# best mean dice: 0.5256 at epoch: 1
# ----------
# epoch 11/50
# 1/70, train_loss: 0.4781
# 2/70, train_loss: 1.0217
# 3/70, train_loss: 1.0011
# 4/70, train_loss: 0.9944
# 5/70, train_loss: 1.0036
# 6/70, train_loss: 1.0000
# 7/70, train_loss: 1.0000
# 8/70, train_loss: 1.0000
# 9/70, train_loss: 0.9565
# 10/70, train_loss: 0.9953
# 11/70, train_loss: 0.9962
# 12/70, train_loss: 1.0004
# 13/70, train_loss: 1.0004
# 14/70, train_loss: 1.0000
# 15/70, train_loss: 1.0020
# 16/70, train_loss: 1.0003
# 17/70, train_loss: 0.9777
# 18/70, train_loss: 1.0000
# 19/70, train_loss: 0.9756
# 20/70, train_loss: 0.9410
# 21/70, train_loss: 0.9200
# 22/70, train_loss: 0.9985
# 23/70, train_loss: 0.9909
# 24/70, train_loss: 0.9896
# 25/70, train_loss: 1.0000
# 26/70, train_loss: 0.9436
# 27/70, train_loss: 0.9996
# 28/70, train_loss: 0.9738
# 29/70, train_loss: 1.0035
# 30/70, train_loss: 0.8477
# 31/70, train_loss: 0.9314
# 32/70, train_loss: 1.0020
# 33/70, train_loss: 0.9668
# 34/70, train_loss: 0.9988
# 35/70, train_loss: 1.0001
# 36/70, train_loss: 1.0049
# 37/70, train_loss: 1.0001
# 38/70, train_loss: 1.0034
# 39/70, train_loss: 1.0031
# 40/70, train_loss: 1.0026
# 41/70, train_loss: 1.0000
# 42/70, train_loss: 1.0000
# 43/70, train_loss: 0.9986
# 44/70, train_loss: 0.9121
# 45/70, train_loss: 1.0000
# 46/70, train_loss: 0.9339
# 47/70, train_loss: 1.0000
# 48/70, train_loss: 0.9991
# 49/70, train_loss: 0.9875
# 50/70, train_loss: 0.9120
# 51/70, train_loss: 0.9993
# 52/70, train_loss: 0.9291
# 53/70, train_loss: 0.8718
# 54/70, train_loss: 1.1314
# 55/70, train_loss: 0.9946
# 56/70, train_loss: 1.0069
# 57/70, train_loss: 1.0000
# 58/70, train_loss: 0.9908
# 59/70, train_loss: 0.9987
# 60/70, train_loss: 1.0000
# 61/70, train_loss: 0.9957
# 62/70, train_loss: 1.0000
# 63/70, train_loss: 0.9253
# 64/70, train_loss: 1.0012
# 65/70, train_loss: 0.9753
# 66/70, train_loss: 1.0582
# 67/70, train_loss: 0.9955
# 68/70, train_loss: 1.0000
# 69/70, train_loss: 0.9323
# 70/70, train_loss: 0.9947
# epoch 11 average loss: 0.9781

# %%
epoch

# %%
torch.save({
            'epoch': epoch + 1,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'best_metric': best_metric,
            'best_metric_epoch': best_metric_epoch,
            'epoch_loss_values': epoch_loss_values,
            'metric_values': metric_values
        }, checkpoint_path)

# %%
print(
    f"train completed, best_metric: {best_metric:.4f} "
    f"at epoch: {best_metric_epoch}")

# %%
import matplotlib.pyplot as plt

plt.figure("train", (12, 6))
plt.subplot(1, 2, 1)
plt.title("Epoch Average Loss")
x = [i + 1 for i in range(len(epoch_loss_values))]
y = epoch_loss_values
plt.xlabel("epoch")
plt.plot(x, y)
plt.subplot(1, 2, 2)
plt.title("Val Mean Dice")
x = [val_interval * (i + 1) for i in range(len(metric_values))]
y = metric_values
plt.xlabel("epoch")
plt.plot(x, y)
plt.show()

# %%
model.load_state_dict(torch.load(os.path.join(data_dir, "best_metric_model.pth")))
model.eval()
with torch.no_grad():
    for i, val_data in enumerate(val_loader):
        roi_size = (160, 160, 160)
        sw_batch_size = 4
        val_outputs = sliding_window_inference(val_data["image_petct"].to(device), roi_size, sw_batch_size, model)
        # plot the slice [:, :, 80]
        plt.figure("check", (18, 6))
        plt.subplot(1, 3, 1)
        plt.title(f"image {i}")
        plt.imshow(val_data["image_petct"][0, 0, :, :, 80], cmap="gray")
        plt.subplot(1, 3, 2)
        plt.title(f"label {i}")
        plt.imshow(val_data["image_sg"][0, 0, :, :, 80])
        plt.subplot(1, 3, 3)
        plt.title(f"output {i}")
        plt.imshow(torch.argmax(val_outputs, dim=1).detach().cpu()[0, :, :, 80])
        plt.show()
        if i == 2:
            break
