# %%
import boto3

# Create an S3 client
s3 = boto3.client('s3',aws_access_key_id='ASIA2X3ER3KRE435KTSD',
aws_secret_access_key='upJA7x+U2tfQ6Cd/NKfr1JzX99pRNSYY499h2wWv',
aws_session_token='')

# Specify the bucket name
bucket_name = 'pet-ct-lesions-s3'

# List objects in the bucket
objects = s3.list_objects_v2(Bucket=bucket_name)

# Print the names of the files
for obj in objects.get('Contents', []):
    print(obj['Key'])
# Out:
# ZIP/PETCT_0011f3deaf.zip
# ZIP/PETCT_01140d52d8.zip
# ZIP/PETCT_0117d7f11f.zip
# ZIP/PETCT_0143bab87a.zip
# ZIP/PETCT_01682f60c3.zip
# ZIP/PETCT_0168f65af8.zip
# ZIP/PETCT_0223010e46.zip
# ZIP/PETCT_0225325b91.zip
# ZIP/PETCT_02ba7e20f5.zip
# ZIP/PETCT_0410759456.zip
# ZIP/PETCT_04606080a0.zip
# ZIP/PETCT_048981112f.zip
# ZIP/PETCT_04a4e1c874.zip
# ZIP/PETCT_04ab5c61c9.zip
# ZIP/PETCT_05808cf24e.zip
# ZIP/PETCT_05bed31780.zip
# ZIP/PETCT_05d5a79faf.zip
# ZIP/PETCT_05d8640f52.zip
# ZIP/PETCT_06a46414eb.zip
# ZIP/PETCT_06d55e8295.zip
# ZIP/PETCT_06e7c24059.zip
# ZIP/PETCT_072833774e.zip
# ZIP/PETCT_07574bfa00.zip
# ZIP/PETCT_08212d7f6c.zip
# ZIP/PETCT_08cdb15e0b.zip
# ZIP/PETCT_099b3fd402.zip
# ZIP/PETCT_09ee00bdc6.zip
# ZIP/PETCT_0b57b247b6.zip
# ZIP/PETCT_0b98dbe00d.zip
# ZIP/PETCT_0beb67c923.zip
# ZIP/PETCT_0cda25453b.zip
# ZIP/PETCT_0e2034240b.zip
# ZIP/PETCT_0ea07b421b.zip
# ZIP/PETCT_0f44cec2e6.zip
# ZIP/PETCT_0f4ee9e078.zip
# ZIP/PETCT_0fa313309d.zip
# ZIP/PETCT_1019ae8551.zip
# ...

# %%
import boto3
import os
import zipfile

# Create an S3 client
s3 = boto3.client('s3',aws_access_key_id='ASIA2X3ER3KRE435KTSD',
aws_secret_access_key='upJA7x+U2tfQ6Cd/NKfr1JzX99pRNSYY499h2wWv',
aws_session_token='')


# Specify the bucket name and local directory to save files
bucket_name = 'pet-ct-lesions-s3'
local_directory = 'data'

# List objects in the bucket
objects = s3.list_objects_v2(Bucket=bucket_name)

# Download and unzip each file
for obj in objects.get('Contents', []):
    file_name = obj['Key']
    if file_name.endswith('.zip'):
        # Determine the name of the extraction folder
        extract_folder = os.path.join(local_directory, os.path.splitext(file_name)[0])
        
        # If the folder already exists, skip the download and extraction
        if os.path.exists(extract_folder):
            print(f"Folder '{extract_folder}' already exists. Skipping download and extraction.")
            continue
        
        local_file_path = os.path.join(local_directory, file_name)
        
        # Download the zip file
        s3.download_file(bucket_name, file_name, local_file_path)
        
        # Create the extraction folder
        os.makedirs(extract_folder, exist_ok=True)
        
        # Unzip the file into the new directory
        with zipfile.ZipFile(local_file_path, 'r') as zip_ref:
            zip_ref.extractall(extract_folder)
        
        # Optionally, remove the downloaded zip file after extraction
        os.remove(local_file_path)

# %%
import os

def count_top_level_folders(directory):
    # List all items in the directory
    items = os.listdir(directory)
    
    # Filter out only the top-level folders (exclude files and nested folders)
    folders = [item for item in items if os.path.isdir(os.path.join(directory, item))]
    
    return len(folders)

# Specify the directory name (in this case, 'ZIP')
directory_name = 'data/ZIP'
folder_count = count_top_level_folders(directory_name)
print(f"'{directory_name}' contains {folder_count} top-level folders.")
# Out:
# 'data/ZIP' contains 100 top-level folders.
